# %%
import os, sys
import pytest

sys.dont_write_bytecode = True

# go to repo root
repo_root = "/Workspace/Repos/mariobgallardo@gmail.com/bees_breweries_case"
os.chdir(repo_root)

# run pytest on tests folder
retcode = pytest.main(["tests", "-q", "-p", "no:cacheprovider"])
assert retcode == 0, "Pytest failed. See logs above."
